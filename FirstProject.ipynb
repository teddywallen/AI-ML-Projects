# %%
# 23wallen
# Project 1
# 2/2/23

import scipy
import numpy
import matplotlib
import pandas as pd
import sklearn
import seaborn as sns

# get the ML libraries

from pandas import read_csv
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# now the dataset

url = "StockX-Data-Contest-2019-3.csv"
# names = []
# column (i am told columns are called "classes"? or is it "features"? upadte: they're called attributes I guess -
# individual data points are called "observations) names, empty for now until can see the data
names = ['order-date', 'brand', 'name', 'sale-price', 'retail-price', 'release-date', 'size', 'buyer-city']
# i saw the data so i filled in attribute names
dataset = read_csv(url, names=names)
# ok now some of the data won't be able to be visualized since it has characters like $ for prices
# and characters like / in dates. so i am going to make the data numerical

#look at data before converting stuff
print(dataset.shape)
print(dataset.head(20))

# strip dollar sign from price attributes
dataset['sale-price'] = dataset["sale-price"].str.replace("$", "").str.replace(",", "").astype(int)
dataset["retail-price"] = dataset["retail-price"].str.replace("$", "").str.replace(",", "").astype(int)

# for the dates, we have to make a system for them to be numerical. so we can use
# numerical ANALYSIS. my system is going to be days since
# january 1st 2000, because why not

dataset['order-date'] = pd.to_datetime(dataset['order-date']).apply(lambda x: x.toordinal() - pd.to_datetime("1/1/2000").toordinal())
dataset['release-date'] = pd.to_datetime(dataset['release-date']).apply(lambda x: x.toordinal() - pd.to_datetime("1/1/2000").toordinal())

print(dataset.shape)
print(dataset.head(20))
# Out:
# (99956, 8)
#    order-date   brand                                           name  \
# 0      9/1/17   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1      9/1/17   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2      9/1/17   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3      9/1/17   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4      9/1/17   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
# 5      9/1/17   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
# 6      9/1/17   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-White
# 7      9/1/17   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 8      9/1/17   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 9      9/1/17   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 10     9/1/17   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 11     9/1/17   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 12     9/1/17   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 13     9/1/17   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 14     9/1/17   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 15     9/1/17   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 16     9/1/17   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 17     9/1/17   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 18     9/1/17   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 19     9/1/17   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
#
#    sale-price retail-price release-date  size      buyer-city
# 0      $1,097         $220      9/24/16  11.0      California
# 1        $685         $220     11/23/16  11.0      California
# 2        $690         $220     11/23/16  11.0      California
# 3      $1,075         $220     11/23/16  11.5        Kentucky
# 4        $828         $220      2/11/17  11.0    Rhode Island
# 5        $798         $220      2/11/17   8.5        Michigan
# 6        $784         $220     12/17/16  11.0      California
# 7        $460         $220      4/29/17  10.0        New York
# 8        $465         $220      4/29/17  11.0          Kansas
# 9        $465         $220      4/29/17  11.0         Florida
# 10       $515         $220      4/29/17  11.5      New Jersey
# 11       $473         $220      4/29/17  10.0           Texas
# 12       $460         $220      4/29/17   9.0         Florida
# 13       $570         $220      2/25/17  14.0        Michigan
# 14       $525         $220      2/25/17   8.0        New York
# 15       $658         $220      2/25/17  11.0      California
# 16       $650         $220      2/25/17  11.0  North Carolina
# 17       $610         $220      2/25/17  10.0      New Jersey
# 18       $589         $220      2/25/17   9.0        New York
# 19       $850         $220      2/25/17   5.5        Michigan
# /var/folders/jk/gltwp6353fn8b8807f7jcksm0000gq/T/ipykernel_32082/3492341373.py:49: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataset['sale-price'] = dataset["sale-price"].str.replace("$", "").str.replace(",", "").astype(int)
# /var/folders/jk/gltwp6353fn8b8807f7jcksm0000gq/T/ipykernel_32082/3492341373.py:50: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataset["retail-price"] = dataset["retail-price"].str.replace("$", "").str.replace(",", "").astype(int)
# (99956, 8)
#     order-date   brand                                           name  \
# 0         6453   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1         6453   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2         6453   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3         6453   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4         6453   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
# 5         6453   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
# 6         6453   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-White
# 7         6453   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 8         6453   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 9         6453   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 10        6453   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 11        6453   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 12        6453   Yeezy          Adidas-Yeezy-Boost-350-V2-Cream-White
# 13        6453   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 14        6453   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 15        6453   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 16        6453   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 17        6453   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 18        6453   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
# 19        6453   Yeezy                Adidas-Yeezy-Boost-350-V2-Zebra
#
#     sale-price  retail-price  release-date  size      buyer-city
# 0         1097           220          6111  11.0      California
# 1          685           220          6171  11.0      California
# 2          690           220          6171  11.0      California
# 3         1075           220          6171  11.5        Kentucky
# 4          828           220          6251  11.0    Rhode Island
# 5          798           220          6251   8.5        Michigan
# 6          784           220          6195  11.0      California
# 7          460           220          6328  10.0        New York
# 8          465           220          6328  11.0          Kansas
# 9          465           220          6328  11.0         Florida
# 10         515           220          6328  11.5      New Jersey
# 11         473           220          6328  10.0           Texas
# 12         460           220          6328   9.0         Florida
# 13         570           220          6265  14.0        Michigan
# 14         525           220          6265   8.0        New York
# 15         658           220          6265  11.0      California
# 16         650           220          6265  11.0  North Carolina
# 17         610           220          6265  10.0      New Jersey
# 18         589           220          6265   9.0        New York
# 19         850           220          6265   5.5        Michigan

# %%
# ok, the data looks nice. now we shall look at some more stats
print(dataset.describe())
print(dataset.groupby('order-date').size())
print(dataset.groupby('brand').size())
print(dataset.groupby('name').size())
print(dataset.groupby('sale-price').size())
print(dataset.groupby('retail-price').size())
print(dataset.groupby('release-date').size())
print(dataset.groupby('size').size())
print(dataset.groupby('buyer-city').size())
# Out:
#          order-date    sale-price  retail-price  release-date          size
# count  99956.000000  99956.000000   99956.00000  99956.000000  99956.000000
# mean    6798.892253    446.634719     208.61359   6615.183531      9.344181
# std      144.123103    255.982969      25.20001    235.279580      2.329588
# min     6453.000000    186.000000     130.00000   5656.000000      3.500000
# 25%     6696.000000    275.000000     220.00000   6461.000000      8.000000
# 50%     6841.000000    370.000000     220.00000   6559.000000      9.500000
# 75%     6923.000000    540.000000     220.00000   6789.000000     11.000000
# max     6983.000000   4050.000000     250.00000   6977.000000     17.000000
# order-date
# 6453     23
# 6454     15
# 6455     16
# 6456     17
# 6457     22
#        ...
# 6979    346
# 6980    303
# 6981    445
# 6982    404
# 6983    348
# Length: 531, dtype: int64
# brand
#  Yeezy       72162
# Off-White    27794
# dtype: int64
# name
# Adidas-Yeezy-Boost-350-Low-Moonrock                    100
# Adidas-Yeezy-Boost-350-Low-Oxford-Tan                   70
# Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015            95
# Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016           122
# Adidas-Yeezy-Boost-350-Low-Turtledove                   68
# Adidas-Yeezy-Boost-350-Low-V2-Beluga                   498
# Adidas-Yeezy-Boost-350-V2-Beluga-2pt0                10395
# Adidas-Yeezy-Boost-350-V2-Blue-Tint                   9297
# Adidas-Yeezy-Boost-350-V2-Core-Black-Copper            225
# Adidas-Yeezy-Boost-350-V2-Core-Black-Green             196
# Adidas-Yeezy-Boost-350-V2-Core-Black-Red               302
# Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017          969
# Adidas-Yeezy-Boost-350-V2-Core-Black-White             621
# Adidas-Yeezy-Boost-350-V2-Cream-White                 9097
# Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow          4854
# Adidas-Yeezy-Boost-350-V2-Sesame                      5553
# Adidas-Yeezy-Boost-350-V2-Zebra                      10110
# Air-Jordan-1-Retro-High-Off-White-Chicago              755
# Air-Jordan-1-Retro-High-Off-White-University-Blue     4635
# Air-Jordan-1-Retro-High-Off-White-White                313
# Nike-Air-Force-1-Low-Off-White                         476
# Nike-Air-Force-1-Low-Off-White-Black-White             960
# Nike-Air-Force-1-Low-Off-White-Volt                   1019
# Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100       31
# Nike-Air-Max-90-Off-White                              627
# Nike-Air-Max-90-Off-White-Black                        722
# Nike-Air-Max-90-Off-White-Desert-Ore                   649
# Nike-Air-Max-97-Off-White                              544
# Nike-Air-Max-97-Off-White-Black                        289
# Nike-Air-Max-97-Off-White-Elemental-Rose-Queen         216
# Nike-Air-Max-97-Off-White-Menta                        343
# Nike-Air-Presto-Off-White                              596
# Nike-Air-Presto-Off-White-Black-2018                  1884
# Nike-Air-Presto-Off-White-White-2018                  1883
# Nike-Air-VaporMax-Off-White                            525
# Nike-Air-VaporMax-Off-White-2018                      1591
# Nike-Air-VaporMax-Off-White-Black                     1313
# Nike-Blazer-Mid-Off-White                              501
# Nike-Blazer-Mid-Off-White-All-Hallows-Eve             1435
# Nike-Blazer-Mid-Off-White-Grim-Reaper                 1398
# Nike-Blazer-Mid-Off-White-Wolf-Grey                    288
# Nike-React-Hyperdunk-2017-Flyknit-Off-White            484
# Nike-Zoom-Fly-Mercurial-Off-White-Black                645
# Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange         656
# Nike-Zoom-Fly-Off-White                                435
# Nike-Zoom-Fly-Off-White-Black-Silver                  1222
# Nike-Zoom-Fly-Off-White-Pink                          1359
# adidas-Yeezy-Boost-350-V2-Butter                     11423
# adidas-Yeezy-Boost-350-V2-Static                      4983
# adidas-Yeezy-Boost-350-V2-Static-Reflective           3184
# dtype: int64
# sale-price
# 186     1
# 190     1
# 191     1
# 194     1
# 195     3
#        ..
# 3400    1
# 3500    1
# 3680    1
# 3700    1
# 4050    1
# Length: 1489, dtype: int64
# retail-price
# 130     3622
# 150       31
# 160     6361
# 170     5471
# 190     7095
# 200     2240
# 220    71707
# 250     3429
# dtype: int64
# release-date
# 5656       68
# 5712       95
# 5796      100
# 5841       70
# 5893      122
# 6111      498
# 6171      723
# 6195      621
# 6251      969
# 6265    10110
# 6328     9097
# 6461     3004
# 6514     1939
# 6517       31
# 6531     4854
# 6538    10395
# 6559     9297
# 6636      313
# 6663     1313
# 6678     1591
# 6739     1301
# 6748     4635
# 6755    11423
# 6782     1884
# 6789     1883
# 6811      504
# 6850     2833
# 6860     1222
# 6865      632
# 6901     5553
# 6906     1359
# 6927     1979
# 6934     3184
# 6935     4983
# 6977     1371
# dtype: int64
# size
# 3.5         4
# 4.0      2241
# 4.5      1304
# 5.0      3577
# 5.5      2621
# 6.0      4013
# 6.5      2219
# 7.0      3867
# 7.5      2664
# 8.0      5363
# 8.5      5300
# 9.0      9706
# 9.5      8685
# 10.0    11093
# 10.5     8784
# 11.0     9251
# 11.5     4502
# 12.0     7297
# 12.5      628
# 13.0     4602
# 13.5      147
# 14.0     1791
# 14.5       84
# 15.0      130
# 16.0       79
# 17.0        4
# dtype: int64
# buyer-city
# Alabama                   457
# Alaska                     61
# Arizona                  1398
# Arkansas                  173
# California              19349
# Colorado                  954
# Connecticut              1110
# Delaware                 1242
# District of Columbia      271
# Florida                  6376
# Georgia                  1846
# Hawaii                    383
# Idaho                     107
# Illinois                 3782
# Indiana                  1026
# Iowa                      460
# Kansas                    340
# Kentucky                  488
# Louisiana                 537
# Maine                     132
# Maryland                 1870
# Massachusetts            2903
# Michigan                 2762
# Minnesota                 725
# Mississippi               163
# Missouri                  660
# Montana                    49
# Nebraska                  245
# Nevada                    790
# New Hampshire             241
# New Jersey               4720
# New Mexico                231
# New York                16525
# North Carolina           1344
# North Dakota               64
# Ohio                     1890
# Oklahoma                  412
# Oregon                   7681
# Pennsylvania             3109
# Rhode Island              347
# South Carolina            570
# South Dakota               55
# Tennessee                 731
# Texas                    5876
# Utah                      450
# Vermont                    84
# Virginia                 2058
# Washington               1863
# West Virginia             166
# Wisconsin                 840
# Wyoming                    40
# dtype: int64

# %%
# hmm, the shoe with the most sales are the butter yeezys, which is weird because nobody likes them. Anyway
# second and third place go to beluga and zebra yeezys. lotta yeezys
# also the retail price is disproportionally $220, which is the retail price for yeezys
# release dates follow the most sold models
# sizes 9-11 most popular
# California had most sales by far

# now lets graph stuff
dataset.plot(kind='box', subplots=True, layout=(5,5), sharex=False, sharey=False, figsize=(15,15))
dataset.hist(figsize=(10,10))
pyplot.show()
scatter_matrix(dataset)
pyplot.show()

# %%
# that only works for the sales and dates data since it's numerical
# more graphs for non-numerical data

dataset.pivot_table(index="brand", aggfunc=len).plot(kind="bar")
pyplot.show()
dataset.pivot_table(index="name", aggfunc=len).plot(kind="bar")
pyplot.show()
dataset.pivot_table(index="buyer-city", aggfunc=len).plot(kind="bar")
pyplot.show()

# %%
# splitting the data
# we are going to have the model predict the 'name' attribute of the shoes
# using only the numerical attributes (so excluding brand and city) since i don't know
# how to use algorithms for non-numerical data (is that possible?)
jarray = dataset.values
james = jarray[:, [0,3,4,5,6]]
bond = jarray[:,2]
James_Train, James_Validation, Bond_Train, Bond_Validation = train_test_split(james, bond, test_size = 0.2, random_state =1)
# adding algorithms to test
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
# evaluating accuracy of each model
# WARNING: this code takes pretty long to load (like 2-5 minutes)
# because I'm using 10 splits for over 40,000 observations
# but the (classified) models are very super accurate so that's cool
# the linear ones are quite inaccurate (expected based on the scatterplots)
results = []
names = []
for name, model in models:
 kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
 cv_results = cross_val_score(model, James_Train, Bond_Train, cv=kfold, scoring='accuracy')
 results.append(cv_results)
 names.append(name)
 print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# LR: 0.503602 (0.002544)
# LDA: 0.354397 (0.002427)
# KNN: 0.972238 (0.001757)
# CART: 0.985343 (0.000944)
# NB: 0.975151 (0.000895)

# %%
# most accurate model = CART
model = DecisionTreeClassifier()
model.fit(James_Train, Bond_Train)
# predicting test data
predictions = model.predict(James_Validation)
# how accurate
print(accuracy_score(Bond_Validation, predictions))
# confusion matrix (truncated)
print(confusion_matrix(Bond_Validation, predictions))
# total classifications
print(classification_report(Bond_Validation, predictions))
# Out:
# 0.9859943977591037
# [[  17    0    0 ...    0    0    0]
#  [   0   12    0 ...    0    0    0]
#  [   0    0   18 ...    0    0    0]
#  ...
#  [   0    0    0 ... 2231    0    0]
#  [   0    0    0 ...    0 1008    0]
#  [   0    0    0 ...    0    0  613]]
#                                                    precision    recall  f1-score   support
#
#               Adidas-Yeezy-Boost-350-Low-Moonrock       1.00      1.00      1.00        17
#             Adidas-Yeezy-Boost-350-Low-Oxford-Tan       1.00      1.00      1.00        12
#      Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015       1.00      1.00      1.00        18
#      Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016       1.00      1.00      1.00        22
#             Adidas-Yeezy-Boost-350-Low-Turtledove       1.00      1.00      1.00        12
#              Adidas-Yeezy-Boost-350-Low-V2-Beluga       1.00      1.00      1.00       113
#             Adidas-Yeezy-Boost-350-V2-Beluga-2pt0       1.00      1.00      1.00      2040
#               Adidas-Yeezy-Boost-350-V2-Blue-Tint       1.00      1.00      1.00      1909
#       Adidas-Yeezy-Boost-350-V2-Core-Black-Copper       0.70      0.50      0.58        56
#        Adidas-Yeezy-Boost-350-V2-Core-Black-Green       0.52      0.70      0.60        40
#          Adidas-Yeezy-Boost-350-V2-Core-Black-Red       0.95      0.98      0.96        56
#     Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017       1.00      1.00      1.00       211
#        Adidas-Yeezy-Boost-350-V2-Core-Black-White       1.00      1.00      1.00       134
#             Adidas-Yeezy-Boost-350-V2-Cream-White       1.00      1.00      1.00      1847
#      Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow       1.00      1.00      1.00       975
#                  Adidas-Yeezy-Boost-350-V2-Sesame       1.00      1.00      1.00      1080
#                   Adidas-Yeezy-Boost-350-V2-Zebra       1.00      1.00      1.00      2010
#         Air-Jordan-1-Retro-High-Off-White-Chicago       1.00      1.00      1.00       154
# Air-Jordan-1-Retro-High-Off-White-University-Blue       1.00      1.00      1.00       906
#           Air-Jordan-1-Retro-High-Off-White-White       1.00      1.00      1.00        61
#                    Nike-Air-Force-1-Low-Off-White       0.86      0.90      0.88       112
#        Nike-Air-Force-1-Low-Off-White-Black-White       0.95      0.92      0.94       183
#               Nike-Air-Force-1-Low-Off-White-Volt       0.93      0.95      0.94       189
# Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100       1.00      1.00      1.00         8
#                         Nike-Air-Max-90-Off-White       0.98      0.98      0.98       135
#                   Nike-Air-Max-90-Off-White-Black       0.64      0.72      0.68       145
#              Nike-Air-Max-90-Off-White-Desert-Ore       0.69      0.60      0.64       146
#                         Nike-Air-Max-97-Off-White       1.00      1.00      1.00       107
#                   Nike-Air-Max-97-Off-White-Black       0.84      0.93      0.88        57
#    Nike-Air-Max-97-Off-White-Elemental-Rose-Queen       1.00      1.00      1.00        40
#                   Nike-Air-Max-97-Off-White-Menta       0.94      0.86      0.89        69
#                         Nike-Air-Presto-Off-White       0.97      0.97      0.97       112
#              Nike-Air-Presto-Off-White-Black-2018       1.00      1.00      1.00       384
#              Nike-Air-Presto-Off-White-White-2018       1.00      1.00      1.00       363
#                       Nike-Air-VaporMax-Off-White       1.00      1.00      1.00       113
#                  Nike-Air-VaporMax-Off-White-2018       1.00      1.00      1.00       321
#                 Nike-Air-VaporMax-Off-White-Black       1.00      1.00      1.00       262
#                         Nike-Blazer-Mid-Off-White       1.00      1.00      1.00       105
#         Nike-Blazer-Mid-Off-White-All-Hallows-Eve       0.92      0.91      0.91       306
#             Nike-Blazer-Mid-Off-White-Grim-Reaper       0.90      0.91      0.90       276
#               Nike-Blazer-Mid-Off-White-Wolf-Grey       1.00      1.00      1.00        52
#       Nike-React-Hyperdunk-2017-Flyknit-Off-White       1.00      1.00      1.00        92
#           Nike-Zoom-Fly-Mercurial-Off-White-Black       0.94      0.93      0.94       137
#    Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange       0.94      0.94      0.94       142
#                           Nike-Zoom-Fly-Off-White       0.88      0.82      0.85        94
#              Nike-Zoom-Fly-Off-White-Black-Silver       1.00      1.00      1.00       243
#                      Nike-Zoom-Fly-Off-White-Pink       1.00      1.00      1.00       274
#                  adidas-Yeezy-Boost-350-V2-Butter       1.00      1.00      1.00      2231
#                  adidas-Yeezy-Boost-350-V2-Static       1.00      1.00      1.00      1008
#       adidas-Yeezy-Boost-350-V2-Static-Reflective       1.00      1.00      1.00       613
#
#                                          accuracy                           0.99     19992
#                                         macro avg       0.95      0.95      0.95     19992
#                                      weighted avg       0.99      0.99      0.99     19992
